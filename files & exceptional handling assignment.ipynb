# %% [markdown]
# 1. What is the difference between interpreted and compiled languages ?
# - Compiled Language: Code is converted to machine code before execution using a compiler (e.g., C, C++).
#
#  Interpreted Language: Code is executed line-by-line by an interpreter at runtime (e.g., Python, JavaScript).

# %% [markdown]
# 2. What is exception handling in Python ?
# - Exception handling in Python is a way to catch and handle errors so that the program doesn't crash.
#
#  We use:
#
#  try – to write code that might have an error
#
#  except – to handle the error
#
#  finally – to run code no matter what

# %% [markdown]
# 3.  What is the purpose of the finally block in exception handling?
# - The finally block is used to write code that should always run, whether an error happens or not.
#
#  It’s often used for clean-up tasks, like closing files or releasing resources.

# %% [markdown]
# Q4. What is logging in Python?
#
# - Ans: Logging in Python is used to record messages about the program’s execution. It helps in debugging and tracking errors or events.

# %% [markdown]
# Q5. What is the significance of the __del__ method in Python?
#
# - Ans: The __del__ method is called when an object is about to be destroyed. It is used for cleanup activities like closing files or network connections.

# %% [markdown]
# Q6. What is the difference between import and from ... import in Python?
#
# Ans:
#
# import module imports the whole module.
#
# from module import item imports only specific items from the module.

# %% [markdown]
# Q7. How can you handle multiple exceptions in Python?
#
# Ans: You can handle multiple exceptions using multiple except blocks or by using a tuple of exceptions in a single except block.

# %% [markdown]
# Q8. What is the purpose of the with statement when handling files in Python?
#
# Ans: The with statement automatically handles opening and closing files, even if an error occurs. It ensures proper resource management.

# %% [markdown]
# Q9. What is the difference between multithreading and multiprocessing?
#
# Ans: Multithreading runs multiple threads in the same process;
# useful for I/O-bound tasks.
#
# Multiprocessing runs separate processes; useful for CPU-bound tasks and takes full advantage of multiple cores.

# %% [markdown]
# Q10. What are the advantages of using logging in a program?
#
# Ans: Logging helps to track errors, debug code, monitor system behavior, and keep logs for future analysis without using print statements.

# %% [markdown]
# Q11. What is memory management in Python?
#
# Ans: Memory management in Python involves allocating and deallocating memory automatically using a private heap, garbage collector, and reference counting.

# %% [markdown]
# Q12. What are the basic steps involved in exception handling in Python?
#
# Ans:
#
# Use try block to write risky code.
#
# Use except block to catch exceptions.
#
# Optionally use else for code that runs if no error occurs.
#
# Use finally for cleanup code that always runs.

# %% [markdown]
# Q13. Why is memory management important in Python?
#
# Ans: Memory management prevents memory leaks, optimizes performance, and ensures efficient use of resources in programs.

# %% [markdown]
# Q14. What is the role of try and except in exception handling?
#
# Ans:
#
# try block contains code that might raise an error.
#
# except block catches and handles that error to prevent the program from crashing.

# %% [markdown]
# Q15. How does Python's garbage collection system work?
#
# Ans: Python’s garbage collector automatically deletes unused objects using reference counting and cyclic garbage collection to free up memory.

# %% [markdown]
# Q16. What is the purpose of the else block in exception handling?
#
# Ans: The else block runs only if no exception occurs in the try block. It’s useful for running code that should execute only when everything goes smoothly.

# %% [markdown]
# Q17. What are the common logging levels in Python?
#
# Ans:
#
# - DEBUG – Detailed information
#
# - INFO – General events
#
# - WARNING – Something unexpected
#
# - ERROR – A serious problem
#
# - CRITICAL – A very serious error

# %% [markdown]
# Q18. What is the difference between os.fork() and multiprocessing in Python?
# Ans:
#
# - os.fork() creates a child process on Unix systems only.
#
# - multiprocessing works on all platforms and provides a cleaner, object-oriented API.

# %% [markdown]
# Q19. What is the importance of closing a file in Python?
#
# Ans: Closing a file releases system resources and ensures all data is properly written to the file. Unclosed files can lead to data corruption.

# %% [markdown]
# Q20. What is the difference between file.read() and file.readline() in Python?
#
# Ans:
#
# - file.read() reads the entire file content at once.
#
# - file.readline() reads only one line at a time from the file.

# %% [markdown]
# Q21. What is the logging module in Python used for?
#
# Ans: The logging module is used to write log messages to files or console. It helps in tracking events, debugging, and error monitoring.

# %% [markdown]
# Q22. What is the os module in Python used for in file handling?
#
# Ans: The os module provides functions to interact with the operating system, like creating/deleting directories, checking paths, and managing files.

# %% [markdown]
# Q23. What are the challenges associated with memory management in Python?
# Ans:
#
# - Circular references
#
# - Memory leaks in long-running programs
#
# - Unused objects not being collected promptly
#
# - Manual resource management (e.g., closing files)

# %% [markdown]
# Q24. How do you raise an exception manually in Python?
#
#  Ans: You can raise an exception manually using the raise keyword

# %% [markdown]
# Q25. Why is it important to use multithreading in certain applications?
#
# Ans: Multithreading is useful in applications where tasks are I/O-bound (like downloading files or reading inputs) and can run simultaneously to improve performance and responsiveness.

# %%
# 1. How can you open a file for writing in Python and write a string to it
with open("output.txt", "w") as file:
    file.write("Hello, this is a sample text.")

# %%
# 2. Write a Python program to read the contents of a file and print each line
with open("output.txt", "r") as file:
    for line in file:
        print(line.strip())
# Out:
# Hello, this is a sample text.

# %%
# 3. How would you handle a case where the file doesn't exist while trying to open it for reading
try:
    with open("nonexistent.txt", "r") as file:
        print(file.read())
except FileNotFoundError:
    print("The file does not exist.")
# Out:
# The file does not exist.

# %%
# 4. Write a Python script that reads from one file and writes its content to another file
try:
    with open("source.txt", "r") as source:
        content = source.read()
    with open("destination.txt", "w") as dest:
        dest.write(content)
except FileNotFoundError:
    print("Source file not found.")
# Out:
# Source file not found.

# %%
# 5. How would you catch and handle division by zero error in Python
try:
    result = 10 / 0
except ZeroDivisionError:
    print("Cannot divide by zero.")
# Out:
# Cannot divide by zero.

# %%
# 6. Write a Python program that logs an error message to a log file when a division by zero exception occurs
import logging

logging.basicConfig(filename="error.log", level=logging.ERROR)

try:
    result = 10 / 0
except ZeroDivisionError as e:
    logging.error("Division by zero occurred: %s", e)
# Out:
# ERROR:root:Division by zero occurred: division by zero

# %%
# 7. How do you log information at different levels (INFO, ERROR, WARNING) in Python using the logging module
import logging

logging.basicConfig(level=logging.DEBUG)
logging.info("This is an info message.")
logging.warning("This is a warning message.")
logging.error("This is an error message.")
# Out:
# WARNING:root:This is a warning message.
# ERROR:root:This is an error message.

# %%
# 8. Write a program to handle a file opening error using exception handling
try:
    file = open("missing.txt", "r")
except FileNotFoundError:
    print("File not found!")
# Out:
# File not found!

# %%
# 9. How can you read a file line by line and store its content in a list in Python
with open("output.txt", "r") as file:
    lines = file.readlines()
    print(lines)
# Out:
# ['Hello, this is a sample text.']

# %%
# 10. How can you append data to an existing file in Python
with open("output.txt", "a") as file:
    file.write("\nAppended line.")

# %%
# 11. Write a Python program that uses a try-except block to handle an error when attempting to access a dictionary key that doesn't exist
my_dict = {"name": "Vikram"}

try:
    print(my_dict["age"])
except KeyError:
    print("Key not found in dictionary.")
# Out:
# Key not found in dictionary.

# %%
# 12. Write a program that demonstrates using multiple except blocks to handle different types of exceptions
try:
    x = int("abc")
    y = 10 / 0
except ValueError:
    print("ValueError occurred.")
except ZeroDivisionError:
    print("ZeroDivisionError occurred.")
# Out:
# ValueError occurred.

# %%
# 13. How would you check if a file exists before attempting to read it in Python
import os

if os.path.exists("output.txt"):
    with open("output.txt", "r") as file:
        print(file.read())
else:
    print("File does not exist.")
# Out:
# Hello, this is a sample text.
# Appended line.

# %%
# 14. Write a program that uses the logging module to log both informational and error messages
import logging

logging.basicConfig(filename="app.log", level=logging.DEBUG)
logging.info("This is an informational message.")
logging.error("This is an error message.")
# Out:
# ERROR:root:This is an error message.

# %%
# 15. Write a Python program that prints the content of a file and handles the case when the file is empty
try:
    with open("empty.txt", "r") as file:
        content = file.read()
        if content.strip() == "":
            print("The file is empty.")
        else:
            print(content)
except FileNotFoundError:
    print("File not found.")
# Out:
# File not found.

# %%
# 16. Demonstrate how to use memory profiling to check the memory usage of a small program
# STEP 1: Install memory-profiler (only once)
# pip install memory-profiler

# STEP 2: Save this code in a .py file (e.g., memory_test.py)

from memory_profiler import profile

@profile
def my_function():
    data = [i for i in range(100000)]  # Some memory usage
    total = sum(data)
    return total

if __name__ == "__main__":
    my_function()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-27-3f808062208f> in <cell line: 0>()
#       5 # STEP 2: Save this code in a .py file (e.g., memory_test.py)
#       6
# ----> 7 from memory_profiler import profile
#       8
#       9 @profile
#
# ModuleNotFoundError: No module named 'memory_profiler'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %%
# 17. Write a Python program to create and write a list of numbers to a file, one number per line
numbers = [1, 2, 3, 4, 5]

with open("numbers.txt", "w") as file:
    for number in numbers:
        file.write(f"{number}\n")

# %%
# 18. How would you implement a basic logging setup that logs to a file with rotation after 1MB
import logging
from logging.handlers import RotatingFileHandler

logger = logging.getLogger("MyLogger")
logger.setLevel(logging.INFO)

handler = RotatingFileHandler("rotating.log", maxBytes=1_000_000, backupCount=3)
logger.addHandler(handler)

logger.info("Logging with rotation setup.")
# Out:
# INFO:MyLogger:Logging with rotation setup.

# %%
# 19. Write a program that handles both IndexError and KeyError using a try-except block
my_list = [1, 2]
my_dict = {"name": "Vikram"}

try:
    print(my_list[5])
    print(my_dict["age"])
except IndexError:
    print("IndexError caught.")
except KeyError:
    print("KeyError caught.")
# Out:
# IndexError caught.

# %%
# 20. How would you open a file and read its contents using a context manager in Python
with open("output.txt", "r") as file:
    content = file.read()
    print(content)
# Out:
# Hello, this is a sample text.
# Appended line.

# %%
# 21. Write a Python program that reads a file and prints the number of occurrences of a specific word
word_to_find = "sample"
count = 0

with open("output.txt", "r") as file:
    for line in file:
        count += line.lower().count(word_to_find.lower())

print(f"The word '{word_to_find}' occurred {count} times.")
# Out:
# The word 'sample' occurred 1 times.

# %%
# 22. How can you check if a file is empty before attempting to read its contents
import os

if os.path.exists("output.txt") and os.stat("output.txt").st_size == 0:
    print("The file is empty.")
else:
    with open("output.txt", "r") as file:
        print(file.read())
# Out:
# Hello, this is a sample text.
# Appended line.

# %%
# 23. Write a Python program that writes to a log file when an error occurs during file handling
import logging

logging.basicConfig(filename="file_error.log", level=logging.ERROR)

try:
    with open("nonexistentfile.txt", "r") as file:
        content = file.read()
except FileNotFoundError as e:
    logging.error("Error while opening file: %s", e)
# Out:
# ERROR:root:Error while opening file: [Errno 2] No such file or directory: 'nonexistentfile.txt'
